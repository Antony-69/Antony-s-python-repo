# %% [markdown]
# Познайомтесь з основними типами даних. Попракитикуйтесь з простими змінними str та int, списками list, наборами set та словниками dict:

# %%
st_1 = "Hello"
st_2 = 'World'
st_3 = """Hello World"""
st_4 = str(123)
print(type(st_1), " а також ", type(st_2), " а також ", type(st_3), " а також ", type(st_4))
# Out:
# <class 'str'>  а також  <class 'str'>  а також  <class 'str'>  а також  <class 'str'>

# %%
st_out = "звертаємось до обєкта та шукаємо кількість входжень літери 'l':"
print(st_out.capitalize(), st_1.count('l'))
# Out:
# Звертаємось до обєкта та шукаємо кількість входжень літери 'l': 2

# %%
a = "Привіт по буквах"
print(a.split()) # розбиває на слова
for letter in a:
    print("-> ", letter)
# ---
print(a[0])  # перший символ
print(a[7:10])  # слайс з 0 по 6 символ
print(a[10:])
# Out:
# ['Привіт', 'по', 'буквах']
# ->  П
# ->  р
# ->  и
# ->  в
# ->  і
# ->  т
# ->
# ->  п
# ->  о
# ->
# ->  б
# ->  у
# ->  к
# ->  в
# ->  а
# ->  х
# П
# по
# буквах

# %%
b = " Світ по буквах"
print(a + b, a.__add__(b))
# a - b 
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
_ = "Це стрічка"
c = "3"
print("Це початок | " + _ + c)
# Out:
# Привіт по буквах Світ по буквах Привіт по буквах Світ по буквах
# Це початок | Це стрічка3

# %%
s = "давайте почнемо з великої букви. і нове речення"
s1, s2 = s.split('. ')
print(s1.capitalize(), ".", s2.capitalize())
# Out:
# Давайте почнемо з великої букви . І нове речення

# %%
n_1 = 123
n_2 = 12.34
ns_1 = "123"
print(type(n_1), " а також ", type(n_2), " а також ", type(ns_1))
# Out:
# <class 'int'>  а також  <class 'float'>  а також  <class 'str'>

# %%
d = 10000000000
import sys
print(type(d), sys.getsizeof(d))
# Out:
# <class 'int'> 32

# %%
ni_1 = 1_000_000
ni_2 = 1e6
# явно вкзати тип
ni_1 = int(1000000)
ni_2: int|float = "12"
print(ni_1, " а також ", type(ni_2) )
nf_1 = float(12.34)
nf_2 = 12.5
print(nf_1, " належить типу ", type(nf_1), " а також ", nf_2, " належить типу ", type(nf_2))
# Out:
# 1000000  а також  <class 'str'>
# 12.34  належить типу  <class 'float'>  а також  12.5  належить типу  <class 'float'>

# %%
print(type(ni_1), ni_1.is_integer(), type(nf_1), nf_1.is_integer())
# Out:
# <class 'int'> True <class 'float'> False

# %%
s1 = "100"
s2 = "Це явно не число"
n1 = 10
n2 = int(s1)
print("Типи заданих змінних: ", type(s1), type(s2), type(n1), type(n2))

print(n1 + n2)
print(s1.isdigit(), s1 + s2)
print(int(s1) + n1)
# Out:
# Типи заданих змінних:  <class 'str'> <class 'str'> <class 'int'> <class 'int'>
# 110
# True 100Це явно не число
# 110

# %%
# Приклад санітизації даних з input
user_input = input("Введіть число: ")
print("Тип введених даних: ", type(user_input))
if user_input.isdigit():
    number = int(user_input)
    print("Ви ввели число:", number)
else:
    print("Помилка: потрібно ввести саме число!")
# Out:
# Тип введених даних:  <class 'str'>
# Ви ввели число: 69

# %%
i = 10
f = 10.0
print(type(i), type(f))
print(i == f)
print(i is f)  # перевірка на ідентичність обєктів
print(i.bit_length(), f.is_integer())
n: int = 1
n += 1.0 # неявне перетворення
type(n)
if isinstance(n, int):
    print("n is float")
else:
    print("помилка")

a: int = 10000
b: float = 0.0000000000125
print("a - b =", a - b, "Чому такий результат?")
# Out:
# <class 'int'> <class 'float'>
# True
# False
# 4 True
# помилка
# a - b = 9999.999999999987 Чому такий результат?

# %%
def func():
    pass

list_1 = [1, 2.0, 3, "hello", 4.5, [5, 6, 7], None, func]
list_1.append("new item")
list_1.remove(2.0)
list_1.pop(3)
print(list_1)
print(list_1[0:3]) # слайс з 0 по 2 індекс
# індексування
list_1[3][-1] = "world"
print(list_1)
# Out:
# [1, 3, 'hello', [5, 6, 7], None, <function func at 0x0000024CE980E8E0>, 'new item']
# [1, 3, 'hello']
# [1, 3, 'hello', [5, 6, 'world'], None, <function func at 0x0000024CE980E8E0>, 'new item']

# %%
s = "Hello"
list_s = list(s)
print(list_s)
s2 = '\n'
print("Це змінна з пустою стрічкою:", s2, "її довжина:", len(s2))
print(s2.join(list_s))
# Out:
# ['H', 'e', 'l', 'l', 'o']
# Це змінна з пустою стрічкою:
#  її довжина: 1
# H
# e
# l
# l
# o

# %%
t = tuple([1, 2, 3, 1, 2, 3]) # перетворення списку у кортеж
print( t )
t2 = (1, 2.0, 3, "hello", 4.5, (5, 6, 7), None, func) # кортеж (tuple) - immutable колекція
print(t2)
a = t.count(1)
print(len(t), a, t.index(3))
# Out:
# (1, 2, 3, 1, 2, 3)
# (1, 2.0, 3, 'hello', 4.5, (5, 6, 7), None, <function func at 0x0000024CE980E8E0>)
# 6 2 2

# %%
# Список покупок (list) — змінюється
shopping_list = ["хліб", "молоко", "яйця"]
print("Початковий список:", shopping_list)
shopping_list.append("сир") # додаємо новий товар
shopping_list[0] = "батон" # змінюємо перший елемент
print("Оновлений список:", shopping_list)

# Координати точки (tuple) — не змінюється
point = (10, 20)
print("Координати точки:", point)
try:
    point[0] = 15 # спроба змінити координату
except TypeError as e:
    print("Помилка:", e)
# Out:
# Початковий список: ['хліб', 'молоко', 'яйця']
# Оновлений список: ['батон', 'молоко', 'яйця', 'сир']
# Координати точки: (10, 20)
# Помилка: 'tuple' object does not support item assignment

# %%
s = {1, 2, 3, 1, 2, 3} # множина (set) - унікальні значення
print(len(s))
l = [1, int(2), 3, "1", float(2), 3] 
# список (list) - можуть бути дублікати
s = set(l)
print("Початкова колекція:", len(l), l, "Після перетворення в Set:", len(s), s)
i = 2
f = 2.0
# ми не можемо порівнювати напряму 1 is 1.0, бо це різні типи
# # у першому випадку i це вже int який присвоївся в неявному перетворенні
# # коли беремо просто величину 2 то це просто величина без перетворення в обєкт
print(type(i), type(2), type(f), type(2.0))
if i is f: 
    print("Порівнюємо на ідентичність і маємо: True")
else: 
    print("Порівнюємо на ідентичність і маємо: False")
# Out:
# 3
# Початкова колекція: 6 [1, 2, 3, '1', 2.0, 3] Після перетворення в Set: 4 {1, 2, 3, '1'}
# <class 'int'> <class 'int'> <class 'float'> <class 'float'>
# Порівнюємо на ідентичність і маємо: False

# %%
def func(i: int):
    assert type(i) is int, "Згідно визначення вхідних аргументів має бути int а є:" + str(type(i))
    # якщо у функцію передали не  int то ми не будемо виконувати наступний код
    print("Вхідний аргумент:", i)

# %%
d = {"name": 1, 0: "Нуль", 1: 1, "Один": 1, 0: "Перевизначив"}
print(d)
d["Нуль"] = 0
print(d)
print(d[0], d["Нуль"])

Student = {"Прізвище": ["Б", "А"], "Імя": ["Богдан", "Василь"]}
print(Student["Прізвище"][0], Student["Імя"][0])
d.pop(0)
print(d)
# Out:
# {'name': 1, 0: 'Перевизначив', 1: 1, 'Один': 1}
# {'name': 1, 0: 'Перевизначив', 1: 1, 'Один': 1, 'Нуль': 0}
# Перевизначив 0
# Б Богдан
# {'name': 1, 1: 1, 'Один': 1, 'Нуль': 0}

# %%
a = 10
print("Привіт", "Нас", a, "Ми", "почали", "вивчати", "Python")
start = "Привіт"
middle = "Нас"
end = "Ми почали вивчати Python"
final_string = start + " " + middle + " " + str(a) + " " + end
print(final_string)
# це робиться коли є декілька виводів, наприклад stdout і log файл
message = "1. Статус виконання: " + final_string
print("1. Статус виконання: " + final_string)
print(message)
s = "1. Статус виконання: {} {} <<{}>> {}".format(a, a, middle, a)
print(s)
# позиційна вставка дозволяє використовувати один і той же аргумент декілька разів
s2 = "1. Статус виконання: {0} {0} <<{1}>> {0}".format(a, middle)
print(s2)
f = 12.3456789
s3 = "різати стрічки {1:.3s} або обмежувати числа {0:.2f}".format(f, "HelloWorld"[4:7])
print(s3)
s4 = "Вивід: %.2s %.2f" % ("Hello", 12.0003) 
print(s4)
d = {"code": 200, "status": "успішно"}
s5 = "Статус: {status}, код: {code}".format(**d)
print(s5)
s6 = f"Статус: {a}, код: {d['code']}, число: {f:.3f}, стрічка: {'HelloWorld'[4:7]}"
print(s6)
for s in ["a", "ab", "abc", "abcd"]: 
    template = f"Початок: |{s:<10}|" 
    print(template)
# Out:
# Привіт Нас 10 Ми почали вивчати Python
# Привіт Нас 10 Ми почали вивчати Python
# 1. Статус виконання: Привіт Нас 10 Ми почали вивчати Python
# 1. Статус виконання: Привіт Нас 10 Ми почали вивчати Python
# 1. Статус виконання: 10 10 <<Нас>> 10
# 1. Статус виконання: 10 10 <<Нас>> 10
# різати стрічки oWo або обмежувати числа 12.35
# Вивід: He 12.00
# Статус: успішно, код: 200
# Статус: 10, код: 200, число: 12.346, стрічка: oWo
# Початок: |a         |
# Початок: |ab        |
# Початок: |abc       |
# Початок: |abcd      |

# %%
def fun(): 
    return NotImplemented
fun()
def fun(): 
    return
print(fun())
l = [1, 6, 3, 9, 1]
print(l)
print(l.sort())
print(l)
#None = "Правда"

# False = 1 # це неможна, буде помилка
false = True
print("Чому це не є рівним", false == False, "?")
# Out:
# None
# [1, 6, 3, 9, 1]
# None
# [1, 1, 3, 6, 9]
# Чому це не є рівним False ?

# %%
print("щось")

for i in map(min, ["asdf", [1,2,3,124]]):
    print(i)

FOR = 1 # але не можна робити for з малої букви

print(any([1!=2, 5=="5", 0 == False]))
# Out:
# щось
# a
# 1
# True

# %%
help(any)
# Out:
# Help on built-in function any in module builtins:
#
# any(iterable, /)
#     Return True if bool(x) is True for any x in the iterable.
#
#     If the iterable is empty, return False.

# %%
s = "стрічка для виводу"
print(s + "Далі")
print(s + "Наступний рядок" )
print(s + "Далі")

for i in ["Далі", "Наступний рядок", "Далі"]:
    print(s + i)
# Out:
# стрічка для виводуДалі
# стрічка для виводуНаступний рядок
# стрічка для виводуДалі
# стрічка для виводуДалі
# стрічка для виводуНаступний рядок
# стрічка для виводуДалі

# %%
for i in range(5):
    print(s + str(i) + "Вивід for ", i)

i = 0 # лічильник
while i < 5:
    print(s + str(i) + "Вивід while", i)
    i += 1

al = ["a", "b", "c", "d", "e"]
for s in al:
    print(f"В циклі for вивели = {s}")

while al: # поки список не порожній
    print(f"В циклі while вивели = {al.pop(0)}")

#ми робимо переініціалізацію списку бо він став порожнім через поп
al = ["a", "b", "c", "d", "e"]
i = 0
while i < len(al):
    print(f"В циклі while з індексом вивели = {al[i]}")
    i += 1
# Out:
# стрічка для виводу0Вивід for  0
# стрічка для виводу1Вивід for  1
# стрічка для виводу2Вивід for  2
# стрічка для виводу3Вивід for  3
# стрічка для виводу4Вивід for  4
# стрічка для виводу0Вивід while 0
# стрічка для виводу1Вивід while 1
# стрічка для виводу2Вивід while 2
# стрічка для виводу3Вивід while 3
# стрічка для виводу4Вивід while 4
# В циклі for вивели = a
# В циклі for вивели = b
# В циклі for вивели = c
# В циклі for вивели = d
# В циклі for вивели = e
# В циклі while вивели = a
# В циклі while вивели = b
# В циклі while вивели = c
# В циклі while вивели = d
# В циклі while вивели = e
# В циклі while з індексом вивели = a
# В циклі while з індексом вивели = b
# В циклі while з індексом вивели = c
# В циклі while з індексом вивели = d
# В циклі while з індексом вивели = e

# %%
mm_unic = ["червоний", "жовтий", "зелений", "коричневий", "помаранчевий", "синій", "фіолетовий"]
import random
mm = 100 * mm_unic
random.shuffle(mm)
print(f"В мене Пачка з {len(mm)} цукерок M&Ms")

for i in random.sample(range(len(mm)), k=5):
    print(f"Взяли цукерку {i} кольору: {mm[i]}")

i = 0
while i < 5:
    n = random.randint(0, len(mm)-1)
    print(f"Взяли цукерку #{n} кольору:", mm[n])
    i += 1
# Out:
# В мене Пачка з 700 цукерок M&Ms
# Взяли цукерку 572 кольору: жовтий
# Взяли цукерку 342 кольору: коричневий
# Взяли цукерку 488 кольору: червоний
# Взяли цукерку 338 кольору: синій
# Взяли цукерку 345 кольору: фіолетовий
# Взяли цукерку #352 кольору: коричневий
# Взяли цукерку #495 кольору: жовтий
# Взяли цукерку #449 кольору: синій
# Взяли цукерку #451 кольору: помаранчевий
# Взяли цукерку #450 кольору: зелений

# %%
import random

r = None
i = 1
while r != 6:
    r = random.randint(1, 6) # симулює кидання кубика
    print(f"{i}. Випало число на кубику: {r}")
    i += 1

for _ in range(20):
    r = random.randint(1, 6)
    print(f"{_+1}. Випало число на кубику: {r}")
    if r == 6:
        break
# Out:
# 1. Випало число на кубику: 3
# 2. Випало число на кубику: 2
# 3. Випало число на кубику: 5
# 4. Випало число на кубику: 4
# 5. Випало число на кубику: 5
# 6. Випало число на кубику: 4
# 7. Випало число на кубику: 3
# 8. Випало число на кубику: 3
# 9. Випало число на кубику: 3
# 10. Випало число на кубику: 1
# 11. Випало число на кубику: 5
# 12. Випало число на кубику: 3
# 13. Випало число на кубику: 5
# 14. Випало число на кубику: 1
# 15. Випало число на кубику: 4
# 16. Випало число на кубику: 3
# 17. Випало число на кубику: 1
# 18. Випало число на кубику: 4
# 19. Випало число на кубику: 5
# 20. Випало число на кубику: 5
# 21. Випало число на кубику: 6
# 1. Випало число на кубику: 2
# 2. Випало число на кубику: 3
# 3. Випало число на кубику: 2
# 4. Випало число на кубику: 1
# 5. Випало число на кубику: 5
# 6. Випало число на кубику: 5
# 7. Випало число на кубику: 5
# 8. Випало число на кубику: 1
# 9. Випало число на кубику: 2
# 10. Випало число на кубику: 4
# 11. Випало число на кубику: 1
# 12. Випало число на кубику: 5
# 13. Випало число на кубику: 5
# 14. Випало число на кубику: 5
# 15. Випало число на кубику: 1
# 16. Випало число на кубику: 3
# 17. Випало число на кубику: 3
# 18. Випало число на кубику: 4
# 19. Випало число на кубику: 1
# 20. Випало число на кубику: 2

# %%
for _ in range(0):
    print(0)
else:
    print(1)
print("Це також гарантовано виконається після циклу")

for i in range(5):
    print("Це виведеться завжди", i)
    if i % 2 == 0:
        print("Це парне число, ми його не будемо виводити")
        continue
    if i == 3:
        print("СТОП, ми припиняємо цикл")
        break
    print("Це непарне число:", i)
# Out:
# 1
# Це також гарантовано виконається після циклу
# Це виведеться завжди 0
# Це парне число, ми його не будемо виводити
# Це виведеться завжди 1
# Це непарне число: 1
# Це виведеться завжди 2
# Це парне число, ми його не будемо виводити
# Це виведеться завжди 3
# СТОП, ми припиняємо цикл

# %%
while (s := input("Введіть 'q' щоб вийти: ")) != 'q':
    print("Цикл продовжується")
    if s == 'e':
        print("Пропускаємо решту коду і переходимо до наступної ітерації")
        continue
# Out:
# Цикл продовжується
# Пропускаємо решту коду і переходимо до наступної ітерації

# %%
la = []
for _ in range(20):
    la.append(random.randint(0, _))
print(la)

la2 = [random.randint(0, _) for _ in range(20)]
print(la2)

for i in ["a", "b", "c"]:
    print(f"<{i}")

print("\n".join(f">{i}" for i in ["a", "b", "c"]))
# Out:
# [0, 0, 2, 3, 0, 0, 4, 6, 6, 3, 4, 10, 3, 0, 1, 15, 0, 16, 8, 1]
# [0, 1, 1, 0, 4, 4, 5, 1, 6, 4, 1, 9, 2, 5, 5, 15, 11, 6, 3, 8]
# <a
# <b
# <c
# >a
# >b
# >c

# %%
for f in [None, 0, False, "", [], {},]:
    print(f)
    if f:
        print("Це ніколи не виконається")
# Out:
# None
# 0
# False
#
# []
# {}

# %%
p = [5]
if p:
    print("Це завжди виконається")
p.pop()
if p:
    print("Це ніколи не виконається")

# тут хитрість, коли перша операція повертає True то друга не виконується
# і ми отримуємо в h значення True
h = len(p) > 0 or "Це буде присвоєно при True"
print(h)
#
l = ["Це буде False", "Це буде True"]
print(l[True])
# Out:
# Це завжди виконається
# Це буде присвоєно при True
# Це буде True

# %%
if False:
    pass
else:
    print("Це виконається")
i = [print("Це виконається") if False else print("Тут виведеться")]
type(i)
# Out:
# Це виконається
# Тут виведеться
# list

# %%
for i in range(5):
    if i % 2 == 0:
        print(f"{i} - парне число")
    else:
        print(f"{i} - непарне число")

i = [print(f"{i} - парне число") for i in range(5) if i % 2 == 0]
# Out:
# 0 - парне число
# 1 - непарне число
# 2 - парне число
# 3 - непарне число
# 4 - парне число
# 0 - парне число
# 2 - парне число
# 4 - парне число

# %%
import random
print("Цей код виконається, бо ще недойшов до помилки")
p = 2
e = None
for i in range(10):
    k = random.randint(0, 1)
    print(f"і={i}, k={k}")
    try:
        j = i/k
    except (NameError, ZeroDivisionError) as e:
        j = 0
        print(f"Виникла помилка: {e} бо k={k}")
    finally:
        j += 1
        print(f"Значення j={j} після обробки")
print("Цей код не виконається, бо дійшов до помилки")
# Out:
# Цей код виконається, бо ще недойшов до помилки
# і=0, k=1
# Значення j=1.0 після обробки
# і=1, k=1
# Значення j=2.0 після обробки
# і=2, k=0
# Виникла помилка: division by zero бо k=0
# Значення j=1 після обробки
# і=3, k=0
# Виникла помилка: division by zero бо k=0
# Значення j=1 після обробки
# і=4, k=0
# Виникла помилка: division by zero бо k=0
# Значення j=1 після обробки
# і=5, k=0
# Виникла помилка: division by zero бо k=0
# Значення j=1 після обробки
# і=6, k=1
# Значення j=7.0 після обробки
# і=7, k=1
# Значення j=8.0 після обробки
# і=8, k=1
# Значення j=9.0 після обробки
# і=9, k=0
# Виникла помилка: division by zero бо k=0
# Значення j=1 після обробки
# Цей код не виконається, бо дійшов до помилки

# %%
f = open("test.txt", "a")
f.write("Це тестовий файл\n")
f.write("Другий рядок файлу\n")
f.write("Ще один рядок файлу\n")
f.close()

# Це видасть помилку оскільки файл вже закрито
#f.write("Спроба запису після закриття файлу\n")

# Використання контекст менеджера для роботи з файлами
with open("test.txt", "a") as f:
    f.write(">> = Це тестовий файл\n")
    f.write(">> = Другий рядок файлу\n")
    f.write(">> = Ще один рядок файлу\n")


# Це видасть помилку оскільки файл вже закрито після виходу з блоку with
#f.write("Спроба запису після закриття файлу\n")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[47], line 2
#       1 f = open("test.txt", "a")
# ----> 2 f.write("Це тестовий файл\n")
#       3 f.write("Другий рядок файлу\n")
#       4 f.write("Ще один рядок файлу\n")
#
# File c:\Users\Antony\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 0-1: character maps to <undefined>

# %%
# Створюємо текст для запису
text1 = "Це перший рядок тексту\n"
text2 = "Це другий рядок тексту\n"
text3 = "Це шостий рядок тексту\n"

# Відкриваємо файл та записуємо дані
with open("test.txt", "w") as f:
    f.write(text1)  # Записуємо в перший рядок
    f.write(">> " + text1)
    f.write(text2)  # Записуємо в другий рядок
    f.write("\n" * 3)  # Пропускаємо 3 рядки
    f.write(text3)  # Записуємо в шостий рядок
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[51], line 8
#       6 # Відкриваємо файл та записуємо дані
#       7 with open("test.txt", "w") as f:
# ----> 8     f.write(text1)  # Записуємо в перший рядок
#       9     f.write(">> " + text1)
#      10     f.write(text2)  # Записуємо в другий рядок
#
# File c:\Users\Antony\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 0-1: character maps to <undefined>

# %%
def write_to_file(f):
    f.write(">>" + text1)  # Записуємо в перший рядок
    f.write(text2)  # Записуємо в другий рядок
    f.write("\n" * 5)  # Пропускаємо 3 рядки
    f.write(text3)  # Записуємо в шостий рядок

with open("test.txt", "w") as f:
    write_to_file(f)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[49], line 8
#       5     f.write(text3)  # Записуємо в шостий рядок
#       7 with open("test.txt", "w") as f:
# ----> 8     write_to_file(f)
#
# Cell In[49], line 2, in write_to_file(f)
#       1 def write_to_file(f):
# ----> 2     f.write(">>" + text1)  # Записуємо в перший рядок
#       3     f.write(text2)  # Записуємо в другий рядок
#       4     f.write("\n" * 5)  # Пропускаємо 3 рядки
#
# File c:\Users\Antony\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 2-3: character maps to <undefined>

# %%
def my_fun():
    print("Це вивід функції")

print(type(my_fun))
# зверху я передав невикликану функцію

def new_fun(i):
    print("З new")
    i()
    print("Завершили")

new_fun(my_fun)

def my_print(s: str):
    """Функція для виведення тексту на екран.
    
    Args:
        s (str): Текстовий рядок для виведення
    """
    print(s)

my_print("Тест")
# Out:
# <class 'function'>
# З new
# Це вивід функції
# Завершили
# Тест

# %%
def add(a, b):
    return a + b

print(add(1,2), 1+2)

c = lambda a,b: a + b
print(type(add), type(c))
print(add(1,2), c(1,2))
# Out:
# 3 3
# <class 'function'> <class 'function'>
# 3 3

# %%
for s in map(lambda a: f"Виводимо переданий аргумент {a}", [1, "1", "Два"]):
    print(s)
# Out:
# Виводимо переданий аргумент 1
# Виводимо переданий аргумент 1
# Виводимо переданий аргумент Два

# %%
import random

print(f"ми запустили гру, та кинули кубик\nНам випало число: {random.randint(1,6)}")

def play():
    print("ми запустили гру, та кинули кубик")
    return random.randint(1,6)

print(f"Нам випало число: {play()}")
# Out:
# ми запустили гру, та кинули кубик
# Нам випало число: 6
# ми запустили гру, та кинули кубик
# Нам випало число: 6

# %%
# звичайна функція
def add(x, y):
    return x + y

# лямбда-еквівалент
add_lambda = lambda x, y: x + y

print(add(2, 3))        # 5
print(add_lambda(2, 3)) # 5
# Out:
# 5
# 5

# %%
a = "змінна з текстом"
b = 1 # числова Змінна
b1 = 1.1 
c = ["a", 1, 1.25, "Слово", a] # List
d = {"a": "Слово", "b": 1, a: b} # Dict
e = ("a", a) # Tuple
f = {"ss", a + str(b)}  # виправлено: число перетворено на рядок

print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# змінна з текстом
# 1
# ['a', 1, 1.25, 'Слово', 'змінна з текстом']
# {'a': 'Слово', 'b': 1, 'змінна з текстом': 1}
# ('a', 'змінна з текстом')
# {'ss', 'змінна з текстом1'}

# %%
print("Перша константа: ", True)
print(f"Як можна так робити вивід? {True}")
print(f"Третя константа: {None}")
import sys
help("keywords")
# Out:
# Перша константа:  True
# Як можна так робити вивід? True
# Третя константа: None
#
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
print(abs(-12.5), f"є рівним {abs(12.5)}", "і якщо порівняти то: ", abs(-12.5) == abs(12.5))
print(len("Python"))
print(round(3.14159, 2))
# Out:
# 12.5 є рівним 12.5 і якщо порівняти то:  True
# 6
# 3.14

# %%
letters = ["a", "b", "c"]
for i in range(len(letters)):
    print(f"На позиції {i} знаходиться буква {letters[i]}")
else:
    print("Ця конструкція безглузда!")

count = 0
while count < 3:
    print("Це цикл while:", count)
    count += 1
# Out:
# На позиції 0 знаходиться буква a
# На позиції 1 знаходиться буква b
# На позиції 2 знаходиться буква c
# Ця конструкція безглузда!
# Це цикл while: 0
# Це цикл while: 1
# Це цикл while: 2

# %%
from random import randint
A = randint(0, 1)
print(f"Значить А={A}" if A else "Але може бути що А={}".format(A))

x = int(input("Введи число: "))
if x > 0:
    print("Число додатнє")
elif x < 0:
    print("Число від’ємне")
else:
    print("Це нуль")
# Out:
# Значить А=1
# Число додатнє

# %%
try:
    my_list = [1, 2, 3]
    print("Четвертий елемент:", my_list[3])  # тут буде помилка IndexError
except IndexError as e:
    print("Ой, сталася помилка:", e)
finally:
    print("Цей блок виконується завжди, незалежно від помилок.")
# Out:
# Ой, сталася помилка: list index out of range
# Цей блок виконується завжди, незалежно від помилок.

# %%
try:
    with open("test.txt", "r") as f:
        for _, line in enumerate(f):
            print(f"{_})> ", line)
except FileNotFoundError:
    print("Файл test.txt не знайдено.")

# %%
def a_b_func(a, b):
    return a, b

this_is_lambda = lambda first, age: f'Цей код написав: {first}, Мені {age:10d} років'
print("Це просто функція:", a_b_func, "\nА це лямбда:", this_is_lambda)
print("Це її виклик:", this_is_lambda('Дмитро', 1_00_000))
print(this_is_lambda(*a_b_func("a", 1)))

this_is_lambda = lambda first, age: f'Цей код написав: {first}, Мені {age:10d} років'
print(this_is_lambda('Дмитро', 100))
# Out:
# Це просто функція: <function a_b_func at 0x0000024CE9B011C0>
# А це лямбда: <function <lambda> at 0x0000024CE9B01440>
# Це її виклик: Цей код написав: Дмитро, Мені     100000 років
# Цей код написав: a, Мені          1 років
# Цей код написав: Дмитро, Мені        100 років
